# %% [markdown]
# # Get reviews from Google Maps

# %% [markdown]
# To use the Google maps API you need to create a free Google maps API key:
#
# https://developers.google.com/places/web-service/get-api-key#creating-api-keys
#
#
# ### Note:
# - We don't need all the reviews of a place, we just need the number of reviews and the average rating
# - Google maps API returns up to 60 places for request ([see here](https://stackoverflow.com/questions/9614258/how-to-get-20-result-from-google-places-api)), so we will need a different approach
#
# ### Approach
# 1. Cover the map with circles of 1km radius
# 2. Make requests for given restaurant for each circle
# 3. List all the restaurants and adjust the rating with bayesian average

# %% [markdown]
# ## Install and import libraries

# %%
! pip install -U googlemaps
! pip install folium

import time
import folium
import googlemaps

import pandas as pd

from math import radians, cos
from shapely.geometry import box
from geopy.geocoders import Nominatim
from math import radians, sin, cos, sqrt, atan2
# Out:
# Requirement already satisfied: googlemaps in /usr/local/lib/python3.10/dist-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.11.17)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.11.17)

# %% [markdown]
# # Variables

# %%
# Your Google maps API key
YOUR_API_KEY = 'AIzaSyCVk--wyWHzK2uilGmx_wySWwdzW8nx0Wk'

# Define the location
location = 'Milano, Italy'

# Define the keyword to search for in restaurant names
keyword = 'Kebab'

# Radius in km
radius = 4

# %% [markdown]
# # Visualize the bounding box

# %%
# Coordinates for the bounding box
def get_city_coordinates(city_name):
    # Given city name return latitude and longitude
    geolocator = Nominatim(user_agent="city_locator")
    location = geolocator.geocode(city_name)
    return (location.latitude, location.longitude)

def create_bounding_box(center, radius_km):
    # Convert radius from kilometers to degrees
    radius_deg = radius_km / 111.32

    # Calculate bounding box coordinates
    lat, lon = center
    lat_min = lat - radius_deg
    lat_max = lat + radius_deg
    lon_min = lon - radius_deg / cos(radians(lat))
    lon_max = lon + radius_deg / cos(radians(lat))

    return [(lat_min, lon_min), (lat_max, lon_max)]

# Compute center coordinates
center_coordinates = get_city_coordinates(city_name=location)

# Compute the coordinates of the bounding box
box_coordinates = create_bounding_box(center=center_coordinates, radius_km=radius)

# Extract the coordinates
sw_lat, sw_lon, ne_lat, ne_lon = box_coordinates[0][0], box_coordinates[0][1], box_coordinates[1][0], box_coordinates[1][1]

# Create a bounding box using Shapely
bounding_box = box(ne_lon, ne_lat, sw_lon, sw_lat)

# Calculate the center of the bounding box
center_lon, center_lat = bounding_box.centroid.coords[0]

# Create a folium map centered around Milan
city_map = folium.Map(location=[center_lat, center_lon], zoom_start=13)

# Create a GeoJSON object for the bounding box
bounding_box_geojson = folium.GeoJson(bounding_box.__geo_interface__, style_function=lambda x: {'fillColor': 'orange', 'color': 'red'})

# Add the bounding box overlay to the map
bounding_box_geojson.add_to(city_map)

# Display the map
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5726d37401349bc0963b878ada1978b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5726d37401349bc0963b878ada1978b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5726d37401349bc0963b878ada1978b8 = L.map(
#                 &quot;map_5726d37401349bc0963b878ada1978b8&quot;,
#                 {
#                     center: [45.464194299999996, 9.1896346],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b43ece69e5828324cfd8102bce7ca74e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5726d37401349bc0963b878ada1978b8);
#
#
#         function geo_json_6e372c7cfe1dcfd829630f62cc544f3c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_6e372c7cfe1dcfd829630f62cc544f3c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6e372c7cfe1dcfd829630f62cc544f3c = L.geoJson(null, {
#                 onEachFeature: geo_json_6e372c7cfe1dcfd829630f62cc544f3c_onEachFeature,
#
#                 style: geo_json_6e372c7cfe1dcfd829630f62cc544f3c_styler,
#         });
#
#         function geo_json_6e372c7cfe1dcfd829630f62cc544f3c_add (data) {
#             geo_json_6e372c7cfe1dcfd829630f62cc544f3c
#                 .addData(data)
#                 .addTo(map_5726d37401349bc0963b878ada1978b8);
#         }
#             geo_json_6e372c7cfe1dcfd829630f62cc544f3c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[9.138401694667307, 45.50012674699964], [9.138401694667307, 45.428261853000365], [9.240867505332693, 45.428261853000365], [9.240867505332693, 45.50012674699964], [9.138401694667307, 45.50012674699964]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Visualize the circles

# %%
# Function to calculate Haversine distance between two points
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Radius of the Earth in kilometers

    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c

    return distance

# number of division
n_div = 5

# create the steps
lat_step = (sw_lat - ne_lat) / n_div
lon_step = (sw_lon - ne_lon) / n_div

# create the boxes
list_of_boxes = []

# list of circles
list_of_circles = []

# rad_coordinates_list
rad_coord_list = []

for i in range(n_div):
  for j in range(n_div):
    # current_box = box(ne_lon + (j-1)*lon_step, ne_lat + (i-1)*lat_step, ne_lon + j*lon_step, ne_lat+ i*lat_step)
    current_box = box(ne_lon + j*lon_step, ne_lat + i*lat_step, ne_lon + (j+1)*lon_step, ne_lat+ (i+1)*lat_step)
    list_of_boxes.append(current_box)

    # Calculate the center of the bounding box
    center_lon, center_lat = current_box.centroid.coords[0]

    # Calculate the distance from the center to each corner of the bounding box
    distances = [
        haversine_distance(center_lat, center_lon, corner[1], corner[0])
        for corner in current_box.exterior.coords
    ]

    # The radius is the maximum distance
    radius = max(distances)

    # Create a folium map centered around the calculated center
    map_center = [center_lat, center_lon]
    city_map = folium.Map(location=map_center, zoom_start=14)

    # Add a circle to the map
    circle = folium.Circle(
        location=map_center,
        radius=radius * 1000,  # Radius in meters
        color='blue',
        fill=True,
        fill_color='blue'
    )

    # add to the list of circles
    list_of_circles.append(circle)

    rad_coord_list.append({
        "center": map_center,
        "radius": radius,
    })

# Calculate the center of the bounding box
center_lon, center_lat = bounding_box.centroid.coords[0]

# Create a folium map centered around the city
city_map = folium.Map(location=[center_lat, center_lon], zoom_start=13)

for circle in list_of_circles:

  # add the circle
  circle.add_to(city_map)

# Add the bounding box overlay to the map
bounding_box_geojson.add_to(city_map)

# Display the map
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f7ac6852752faff826680fda29e6947 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f7ac6852752faff826680fda29e6947&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f7ac6852752faff826680fda29e6947 = L.map(
#                 &quot;map_6f7ac6852752faff826680fda29e6947&quot;,
#                 {
#                     center: [45.464194299999996, 9.1896346],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_486e64ade68072ac0c20ed4581a9fd1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_8c86fb32fe426b555b88adb01b7c0775 = L.circle(
#                 [45.49294025759971, 9.230620924266157],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.8475644889988, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_52465e30349a9ce504296efeae1278d4 = L.circle(
#                 [45.49294025759971, 9.210127762133077],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.8475644888238, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_d9e13eb94dd5026bf4685e290dd94508 = L.circle(
#                 [45.49294025759971, 9.1896346],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.8475644889113, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_035c38c55c7810d086f27256978b35eb = L.circle(
#                 [45.49294025759971, 9.169141437866921],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.8475644889113, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_681a1d03dc2803ca4f103e8f6be25790 = L.circle(
#                 [45.49294025759971, 9.148648275733844],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.8475644889113, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);
#
#
#             var circle_7872fb0bbec1b892a8962c866414ca19 = L.circle(
#                 [45.478567278799865, 9.230620924266157],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1129.991647575342, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f7ac6852752faff826680fda29e6947);

# %% [markdown]
# # Google maps requests

# %%
# Replace 'YOUR_API_KEY' with your actual Google Maps API key
gmaps = googlemaps.Client(key=YOUR_API_KEY)
# 'AIzaSyCVk--wyWHzK2uilGmx_wySWwdzW8nx0Wk'

# list containing all the places
complete_list = []
list_of_places = []

for circle in rad_coord_list:

  # Perform a Places API text search
  places_result = gmaps.places_nearby(
      location=circle["center"],
      radius=circle["radius"]*1000,
      keyword=keyword,
      type="restaurant",
      #pagetoken=None,
      )

  print(f"\n *** Kebab in current circle: {len(places_result['results'])} *** \n ")

  # Extract relevant information from the results
  for place in places_result['results']:
    name = place['name']
    address = place.get('vicinity', 'Address not available')
    rating = place["rating"]
    n_rev = place["user_ratings_total"]
    print(f"Name: {name}\nAddress: {address}\n{'='*30}")
    complete_list.append(place)
    list_of_places.append({
        "name": place["name"],
        "address": place["vicinity"],
        "n_reviews": place["user_ratings_total"],
        "rating": place["rating"],
    })
# Out:
#  *** Kebab in current circle: 20 ***
#
# Name: Santa Sofia Istanbul Kebap
# Address: Via Bambaia, 2, Milano
# ==============================
# Name: El.Basha
# Address: Via Padova, 149, Milano
# ==============================
# Name: Kebab Goha di via Padova
# Address: Via Padova, 58, Milano
# ==============================
# Name: Istanbul City Turkish Kebap Pizzeria
# Address: Via Nicola Antonio Porpora, 169, Milano
# ==============================
# Name: İstanbul Girasole Kebap
# Address: Viale Monza, 49, Milano
# ==============================
# Name: BEST TURKISH KEBAP
# Address: Via Giulio e Corrado Venini, 69, Milano
# ==============================
# Name: İstanbul kebap turkişh monte ararat
# Address: Viale Monza, 23, Milano
# ==============================
# Name: Santa Monica
# Address: Viale Abruzzi, 90, Milano
# ==============================
# Name: Padova Pizza Kebab
# Address: Via Padova, 80, Milano
# ==============================
# Name: HELA Chicken Pizza & Kebab
# Address: Via Padova, 181, Milano
# ==============================
# Name: Istanbul Ozkan
# Address: Via Palmanova, 59, Milano
# ==============================
# Name: Hela Pizza Kebab
# Address: Via Padova, 150, Milano
# ==============================
# Name: Istanbul Ayasofya
# Address: Viale Monza, 116, Milano
# ==============================
# Name: Mevlana Kebab
# Address: Milan
# ==============================
# Name: Turkish Kebap
# Address: Milan
# ==============================
# Name: Ayasofya-Santa Sofia Kebap Pizza
# Address: Corso Buenos Aires, 72, Milano
# ==============================
# Name: Oliva Turkish Mediterraneo
# Address: Viale Monza, 56, Milano
# ==============================
# Name: Kebhouze - Buenos Aires
# Address: Corso Buenos Aires, 77A, Milano
# ==============================
# Name: Turkish kebap Pizza ,_ Vle Abruzzi 58 MILANO
# Address: Viale Abruzzi, 58, Milano
# ==============================
# Name: MARVELOUS PIZZA BURGER & KEBAB
# Address: Via Nicola Antonio Porpora, 109/111, Milano
# ==============================
#
#  *** Kebab in current circle: 20 ***
#
# Name
# Name: Kebab e pizza Garibaldi
# Address: Viale Pasubio, 12, Milano
# ==============================
# Name: Istwest
# Address: Viale Marche, 46-60, Milano
# ==============================
# Name: Pizza & Kebap Mekan
# Address: P.za Antonio Baiamonti, 2, Milano
# ==============================
# Name: Istanbul Kebap Restaurant
# Address: Italia, Via Vitruvio, 30, Milano
# ==============================
# Name: Kebab Pizza Cleopatra
# Address: Via Roberto Lepetit, 16, Milano
# ==============================
# Name: Mekan Döner pizzeria Baiamonti
# Address: P.za Antonio Baiamonti, 2, Milano
# ==============================
# Name: Turkish Direzionale Pizza-Grill
# Address: Via Tonale, 8, Milano
# ==============================
# Name: King Kebab Milano
# Address: Milan
# ==============================
# Name: Kebhouze Irish Pub - Isola
# Address: Via Luigi Porro Lambertenghi, 17, Milano
# ==============================
# Name: Pizza Kebab
# Address: Via Carlo Farini, 44, Milano
# ==============================
#
#  *** Kebab in current circle: 20 ***
#
# Name: Blu Istambul
# Address: Corso Sempione, 81, Milano
# ==============================
# Name: İSTANBUL Turkish Kebap
# Address: Via Piero della Francesca, 24, Milano
# ==============================
# Name: Pizzeria Kebap Dergano
# Address: Piazza Dergano, 2, Milano
# ==============================
# Name: Maciachini Istanbul Kebap / Pizza / Grill
# Address: Viale Edoardo Jenner, 14, Milano
# ==============================
# Name: Pizzeria Kebap Istanbul (shımarık)
# Address: Viale Edoardo Jenner, 46, Milano
# ==============================
# Name: Pizzeria & Kebab Pace 2
# Address: Via Carlo Imbonati, 9, Milano
# ==============================
# Name: Bovisa Kebap Pizza
# Address: Via Giovanni Battista Varè, 37, Milano
# ==============================
# Name: Mangal Kebap
# Address: Viale Monte Ceneri, 60, Milano
# ==============================
# Name: Turkish kebap-pizza-grill-Imbonati
# Address: Via Carlo Imbonati, 63, Milano
# ==============================
# Name: Kebab e pizza Garibaldi
# Address: Viale Pasubio, 12, Milano
# ==============================
# Name: PoliBov Istanbul Kebap (Politecnico Bovisa)
# Address: Via Raffaele Lambruschini, 29, Milano
# ==============================
# Name: Pizza & Kebap Mekan
# Address: P.za Antonio Baiamonti, 2, Milano
# ==============================
# Name: Miglior Kebap Di Milano
# Address: Viale Stelvio, 52, Milano
# ==============================
# Name: Doner Kebap
# Address: Milan
# ==============================
# Name: Mekan Döner pizzeria Baiamonti
# Address: P.za Antonio Baiamonti, 2, Milano
# ==============================
# Name: MM Kebap-pizza-grill
# Address: Via Pietro da Cemmo, Milano
# ==============================
# Name: Koki Pizza
# Address: Via Angelo Poliziano, 12, Milano
# ==============================
# Name: Fantasía Kebap - Pizza
# Address: Piazza Prealpi, 5, Milano
# ==============================
# Name: Pizza Kebab
# Address: Via Carlo Farini, 44, Milano
# ==============================
# Name: Dergano Kebap Pizzeria
# Address: Via Carlo Imbonati, 63, Milano
# ==============================
#
#  *** Kebab in current circle: 18 ***
#
# Name: Istanbul aksu kebap pizze grill
# Address: Via Console Marcello, 14, Milano
# ==============================
# Name: Blu Istambul
# Address: Corso Sempione, 81, Milano
# ==============================
# Name: Mangal Kebap
# Address: Viale Monte Ceneri, 60, Milano
# ==============================
# Name: Istanbul in Europa
# Address: Via Marcantonio Colonna, 51, Milano
# Address: Italia, Via Vitruvio, 30, Milano
# ==============================
# Name: Kebab Pizza Cleopatra
# Address: Via Roberto Lepetit, 16, Milano
# ==============================
# Name: Turkish Direzionale Pizza-Grill
# Address: Via Tonale, 8, Milano
# ==============================
# Name: Pasa
# Address: Via Ponte Seveso, 44, Milano
# ==============================
# Name: Kebhouze - Sarpi
# Address: Via Paolo Sarpi, 53, Milano
# ==============================
#
#  *** Kebab in current circle: 12 ***
#
# Name: Blu Istambul
# Address: Corso Sempione, 81, Milano
# ==============================
# Name: İSTANBUL Turkish Kebap
# Address: Via Piero della Francesca, 24, Milano
# ==============================
# Name: Kebab e pizza Garibaldi
# Address: Viale Pasubio, 12, Milano
# ==============================
# Name: Kebab Pizza Istanbul Ayasofya
# Address: Via Manfredo Camperio, 17, Milano
# ==============================
# Name: Pizza & Kebap Mekan
# Address: P.za Antonio Baiamonti, 2, Milano
# ==============================
# Name: Milano Kebap House
# Address: Via Palermo, 18, Milano
# ==============================
# Name: Pizza-Kebab Di Cairoli
# Address: Via Manfredo Camperio, 17, Milano
# ==============================
# Name: Kebhouze - Sarpi
# Address: Via Paolo Sarpi, 53, Milano
# ==============================
# Name: Istanbul ravizza kebap
# Address: Via Carlo Ravizza, 8, Milano
# ==============================
# Name: AYASOFYA TURKISH KEBAP
# Address: Via della Moscova, 39, Milano
# ==============================
# Name: Koki Pizza
# Address: Via Angelo Poliziano, 12, Milano
# ==============================
# Name: Kebhouze - Marghera
# Address: Via Marghera, 24, Milano
# ==============================
#
#  *** Kebab in current circle: 14 ***
#
# Name: Blu Istambul
# Address: Corso Sempione, 81, Milano
# ==============================
# Name: Blu Istanbul - Kebab Pizza Grill
# Address: Via Guglielmo Silva, 45, Milano
# ==============================
# Name: Istanbul Doner Kebab
# Address: Piazzale Selinunte, 6, Milano
# ==============================
# Name: Kebap murillo 33
# Address: Viale Murillo, 33, Milano
# ==============================
# Name: Sila Kebap Pizza
# Address: Via Francesco Albani, 61, Milano
# ==============================
# Name: Istanbul in Europa
# Address: Via Marcantonio Colonna, 51, Milano
# ==============================
# Name: Piazza Falterona Kebap Pízza
# Address: Piazza Monte Falterona, Milano
# ==============================
# Name: İSTANBUL Turkish Kebap
# Address: Via Piero della Francesca, 24, Milano
# ==============================
# Name: Istanbul ravizza kebap
# Address: Via Carlo Ravizza, 8, Milano
# ==============================
# Name: Turkish Kebap Pizza-Grill
# Address: Via Rembrandt, 44, Milano
# ==============================
# Name: Istanbul Firat Kebap
# Address: Piazza Domenico Ghirlandaio, 7, Milano
# ==============================
# Name: Kebhouze - Marghera
# Address: Via Marghera, 24, Milano
# ==============================
# Name: Istanbul Murillo
# Address: Viale Murillo, 33, Milano
# ==============================
# Name: Urfa Turkish Kebap-Pizza
# Address: Viale Teodorico, 32, Milano
# ==============================
#
#  *** Kebab in current circle: 12 ***
#
# Name: CITY ISTANBUL KEBAB & PIZZA
# Address: Via Gaetano Strigelli, 5, Milano
# ==============================
# Name: Istanbul Uskudar Kebap
# Address: Viale Romagna, 23, Milano
# ==============================
# Name: Royal Turkish Kebap Pizza Grill Bar&Cocktail
# Address: Via Torino, 50, Milano
# ==============================
# Name: Duomo Kebap Halal Grill Pizza Turkish
# Address: Via Flavio Baracchini, 7, Milano
# ==============================
# Name: TURKISH KEBAB PİZZA
# Address: Via Caminadella 5 Milano Via Torino Milano Corso Genova via D'Amicis Milano Corso Magenta, Piazza della Resistenza Partigiana, Milano
# ==============================
# Name: Champion Turkish Kebap
# Address: Corso di Porta Ticinese, 83, Milano
# ==============================
# Name: Pizzeria Milano Pizza Kebab Milano
# Address: Via Pace, 23, Milano
# ==============================
# Name: Mina Pizza & Kebab
# Address: Viale Monte Nero, 20, Milano
# ==============================
# Name: Pizza-Kebab Di Cairoli
# Address: Via Manfredo Camperio, 17, Milano
# ==============================
# Name: Milano Kebap House
# Address: Via Palermo, 18, Milano
# ==============================
# Name: Turkish Kebap
# Address: Via della Moscova, 7, Milano
# ==============================
# Name: Sant'Ambrogio
# Address: Via Ausonio, 7, Milano
# ==============================
# Name: Royal Turkish Kebap - Pizza
# Address: Corso Buenos Aires, 2, Milano
# ==============================
# Name: Istanbul Kebap Pizzeria
# Address: Via Cesare Cantù, 2, Milano
# ==============================
# Name: Döner Club Kebab
# Address: Viale Monte Nero, 50, Milano
# ==============================
#
#  *** Kebab in current circle: 15 ***
#
# Name: Kebab Pizza Istanbul Ayasofya
# Address: Via Manfredo Camperio, 17, Milano
# ==============================
# Name: İstanbul
# Address: Corso di Porta Ticinese, 83, Milano
# ==============================
# Name: Champion Turkish Kebap
# Address: Corso di Porta Ticinese, 83, Milano
# ==============================
# Name: Sant'Ambrogio
# Address: Via Ausonio, 7, Milano
# ==============================
# Name: Pizza-Kebab Di Cairoli
# Address: Via Manfredo Camperio, 17, Milano
# ==============================
# Name: Pizzeria kebab dal re
# Address: Viale Coni Zugna, 39, Milano
# ==============================
# Name: Royal Turkish Kebap Pizza Grill Bar&Cocktail
# Address: Via Torino, 50, Milano
# ==============================
# Name: Milano Kebap House
# Address: Via Palermo, 18, Milano
# ==============================
# Name: Kebab Pizzeria Halal Mimi 2
# Address: Via dei Piatti, 2, Milano
# ==============================
# Name: TURKISH KEBAB PİZZA
# Address: Via Caminadella 5 Milano Via Torino Milano Corso Genova via D'Amicis Milano Corso Magenta, Piazza della Resistenza Partigiana, Milano
# ==============================
# Name: Istanbul ravizza kebap
# Address: Via Carlo Ravizza, 8, Milano
# ==============================
# Name: Kebhouze - Porta Genova
# Address: Via Vigevano, 41, Milano
# ==============================
# Name: Kebhouze - Colonne
# Address: Corso di Porta Ticinese, 40, Milano
# ==============================
# Name: Instanbul Kebap
# Address: Via Milano, Cassano d'Adda
# ==============================
# Name: Kebhouze - Marghera
# Address: Via Marghera, 24, Milano
# ==============================
#
#  *** Kebab in current circle: 10 ***
#
# Name: Istanbul Doner Kebab
# Address: Piazzale Selinunte, 6, Milano
# ==============================
# Name: Istanbul ravizza kebap
# Address: Via Carlo Ravizza, 8, Milano
# ==============================
# Name: Istanbul Firat Kebap
# Address: Piazza Domenico Ghirlandaio, 7, Milano
# ==============================
# Name: Marmara Turkish KEBAP E PIZZA
# Address: Piazzale Giovanni delle Bande Nere, 2, Milano
# ==============================
# Name: Piazza Falterona Kebap Pízza
# Address: Piazza Monte Falterona, Milano
# ==============================
# Name: Turkish Kebap Pizza-Grill
# Address: Via Rembrandt, 44, Milano
# ==============================
# Name: Kebhouze - Marghera
# Address: Via Marghera, 24, Milano
# ==============================
# Name: Kebap murillo 33
# Address: Viale Murillo, 33, Milano
# ==============================
# Name: Tripoli
# Address: Viale Caterina da Forlì, 1, Milano
# ==============================
# Name: Istanbul Murillo
# Address: Viale Murillo, 33, Milano
# ==============================
#
#  *** Kebab in current circle: 15 ***
#
# Name: Dream Kebab
# Address: Piazzale Vincenzo Cuoco, 4, Milano
# ==============================
# Name: San Giorgio
# Address: Piazza Insubria, 7, Milano
# ==============================
# Name: CITY ISTANBUL KEBAB & PIZZA
# Address: Via Gaetano Strigelli, 5, Milano
# ==============================
# Name: Kebap Molise
# Address: Viale Molise, 51, Milano
# ==============================
# Name: Pizza Kebab Nada
# Address: Corso Lodi, 105, Milano
# ==============================
# Name: Pizzeria Kebab San Mina
# Address: Piazza Insubria, 5, Milano
# ==============================
# Name: Aksaray Istanbul Kebap
# Address: Corso Lodi, 84, Milano
# ==============================
# Name: Kebab Pizzeria Kirmina
# Address: Viale Umbria, 50, Milano
# ==============================
# Name: Mevlana
# Address: Via Carlo Marochetti, 1, Milano
# ==============================
# Name: Pazarcik Atmali Kebap
# Address: 14, Via Faa' Di Bruno Emilio, Milano, MI 20137, Milano
# ==============================
# Name: Best Turkish Kebap
# Address: Viale Ungheria, 28, Milano
# ==============================
# Name: EURO DONER&PIZZA
# Address: Via Carlo Marochetti, 25, Milano
# ==============================
# Name: Istanbul Kebap
# Address: Via Emilio Faà di Bruno, 14, Milano
# ==============================
# Name: Aksu Turkish Kebap Tavola Calda
# Address: Piazza Geremia Bonomelli, 4, Milano
# ==============================
# Name: Specialità egiziane Casa Nostra
# Address: Viale Lucania, 10, Milano
# ==============================
#
#  *** Kebab in current circle: 20 ***
#
# Name: Dream Kebab
# Address: Piazzale Vincenzo Cuoco, 4, Milano
# ==============================
# Name: ATA Kebab Pizza
# Address: Corso di Porta Romana, 79, Milano
# ==============================
# Name: Lodi Kebab & Pizza
# Address: Corso Lodi, 24, Milano
# ==============================
# Name: San Giorgio
# Address: Piazza Insubria, 7, Milano
# ==============================
# Name: Pizzeria Turkish Kebap
# Address: Viale Umbria, 11, Milano
# ==============================
# Name: Kebab Pizzeria Kirmina
# Address: Viale Umbria, 50, Milano
# ==============================
# Name: Turkish Kebab
# Address: Corso di Porta Romana, 83, Milano
# ==============================
# Name: CITY ISTANBUL KEBAB & PIZZA
# Address: Via Gaetano Strigelli, 5, Milano
# ==============================
# Name: Pizzeria Kebab san francesco
# Address: Viale Umbria, 9, Milano
# ==============================
# Name: Pizza Kebap Senza Cipolla
# Address: Viale Bligny, 64, Milano
# ==============================
# Name: Mina Pizza & Kebab
# Address: Viale Monte Nero, 20, Milano
# ==============================
# Name: Pizzeria Milano Pizza Kebab Milano
# Name: Fantasia Kebap-Pizza
# Address: Milan
# ==============================
#
#  *** Kebab in current circle: 10 ***
#
# Name: Pizza Kebab Nada
# Address: Corso Lodi, 105, Milano
# ==============================
# Name: EURO DONER&PIZZA
# Address: Via Carlo Marochetti, 25, Milano
# ==============================
# Name: Pizzeria - Kebab Mar Rosso
# Address: Via Giovanni Battista Cassinis, 63, Milano
# ==============================
# Name: Aksaray Istanbul Kebap
# Address: Corso Lodi, 84, Milano
# ==============================
# Name: Mevlana
# Address: Via Carlo Marochetti, 1, Milano
# ==============================
# Name: Kebapçi turksse
# Address: Via Marco D'Agrate, 15, Milano
# ==============================
# Name: Best Turkish Kebap
# Address: Viale Ungheria, 28, Milano
# ==============================
# Name: Aksu Turkish Kebap Tavola Calda
# Address: Piazza Geremia Bonomelli, 4, Milano
# ==============================
# Name: Kimos Pizzeria
# Address: Via Bruno Cassinari, 3, Milano
# ==============================
# Name: Specialità egiziane Casa Nostra
# Address: Viale Lucania, 10, Milano
# ==============================
#
#  *** Kebab in current circle: 7 ***
#
# Name: Kebapçi turksse
# Address: Via Marco D'Agrate, 15, Milano
# ==============================
# Name: Pizza Kebab Nada
# Address: Corso Lodi, 105, Milano
# ==============================
# Name: Aksu Turkish Kebap Tavola Calda
# Address: Piazza Geremia Bonomelli, 4, Milano
# ==============================
# Name: Aksaray Istanbul Kebap
# Address: Corso Lodi, 84, Milano
# ==============================
# Name: Mevlana
# Address: Via Carlo Marochetti, 1, Milano
# ==============================
# Name: Istanbul Turkish kebap
# Address: Via Giuseppe Ripamonti, 186, Milano
# ==============================
# Name: Specialità egiziane Casa Nostra
# Address: Viale Lucania, 10, Milano
# ==============================
#
#  *** Kebab in current circle: 10 ***
#
# Name: Turkish Kebap - Pizza
# Address: Viale Giovanni da Cermenate, 25, Milano
# ==============================
# Name: Instanbul Taxim 1
# Address: Via Giuseppe Meda, 57, Milano
# ==============================
# Name: Fly Pizza Kebab
# Address: Via Evangelista Torricelli, 15, Milano
# ==============================
# Name: Ciccio Pasha
# Address: Via Giuseppe Meda, 17, Milano
# ==============================
# Name: İstanbul Meda Kebap Grill
# Address: Via Giuseppe Meda, 6, Milano
# ==============================
# Name: IMPERATOR KEBAP
# Address: Via Lodovico Montegani, 22, Milano
# ==============================
# Name: Mozzarella e Pomodoro
# Address: Via Volvinio, 4, Milano
# ==============================
# Name: Pasa Kebap Pizza
# Address: 20136, Viale Tibaldi 15, via meda 17, Milano
# ==============================
# Name: Istanbul Turkish kebap
# Address: Via Giuseppe Ripamonti, 186, Milano
# ==============================
# Name: Pizzeria San Karas
# Address: Via Frà Cristoforo, 1, Milano
# ==============================
#
#  *** Kebab in current circle: 15 ***
#
# Name: Turkish Kebap - Pizza
# Address: Viale Giovanni da Cermenate, 25, Milano
# ==============================
# Name: Instanbul Taxim 1
# Address: Via Giuseppe Meda, 57, Milano
# ==============================
# Name: Istanbul Turkish Kebab Milano
# Address: Via Ambrogio Binda, 28, Milano
# ==============================
# Name: Turkish Kebap
# Address: Viale Romolo, 1, Milano
# ==============================
# Name: Fly Pizza Kebab
# Address: Via Evangelista Torricelli, 15, Milano
# ==============================
# Name: Ciccio Pasha
# Address: Via Giuseppe Meda, 17, Milano
# ==============================
# Name: İstanbul Meda Kebap Grill
# Address: Via Giuseppe Meda, 6, Milano
# ==============================
# Name: Saray Döner Kebap - Pizza - Grill - Forno a legna
# Address: Piazza Guglielmo Miani, 4, Milano
# ==============================
# Name: IMPERATOR KEBAP
# Address: Via Lodovico Montegani, 22, Milano
# ==============================
# Name: Cassala Turkish Kebap - Pizza - Grill
# Address: Via Carlo Torre, 45, Milano
# ==============================
# Name: Watt turkish Kebap & pizza
# Address: Via Giacomo Watt, 4, Milano
# ==============================
# Name: Mozzarella e Pomodoro
# Address: Via Volvinio, 4, Milano
# ==============================
# Name: Pasa Kebap Pizza
# Address: 20136, Viale Tibaldi 15, via meda 17, Milano
# ==============================
# Name: Pizzeria San Karas
# Address: Via Frà Cristoforo, 1, Milano
# ==============================
# Name: Gengis Khan Pizza & Kebap
# Address: SPexSS11, 32, Milano
# ==============================
#
#  *** Kebab in current circle: 7 ***
#
# Name: Istanbul Turkish Kebab Milano
# Address: Via Ambrogio Binda, 28, Milano
# ==============================
# Name: Saray Döner Kebap - Pizza - Grill - Forno a legna
# Address: Piazza Guglielmo Miani, 4, Milano
# ==============================
# Name: Watt turkish Kebap & pizza
# Address: Via Giacomo Watt, 4, Milano
# ==============================
# Name: Rosticceria Anestom Kebab
# Address: Via Giambellino, 132, Milano
# ==============================
# Name: Cassala Turkish Kebap - Pizza - Grill
# Address: Via Carlo Torre, 45, Milano
# ==============================
# Name: Pascià Kebap & Pizza
# Address: Via Giambellino, 136, Milano
# ==============================
# Name: Bella vista Istanbul 2 kebap
# Address: Via Santa Rita da Cascia, 3, Milano
# ==============================

# %%
# convert the list to df
df = pd.DataFrame(list_of_places)

# remove the duplicates
df = df.drop_duplicates(subset="name").sort_values(by="rating", ascending=False).reset_index(drop="True")

df
# Out:
#                                       name  \
# 0             Naviglio Turkish Kebap Pizza
# 1    Cassala Turkish Kebap - Pizza - Grill
# 2                         EURO DONER&PIZZA
# 3                           Istanbul Kebap
# 4                                 İstanbul
# ..                                     ...
# 160                        Instanbul Kebap
# 161                            Pizza Kebab
# 162               Urfa Turkish Kebap-Pizza
# 163                  Pazarcik Atmali Kebap
# 164                           Santa Monica
#
#                                                address  n_reviews  rating
# 0                   Alzaia Naviglio Pavese, 24, Milano         16     5.0
# 1                          Via Carlo Torre, 45, Milano        104     5.0
# 2                     Via Carlo Marochetti, 25, Milano          2     5.0
# 3                  Via Emilio Faà di Bruno, 14, Milano          1     5.0
# 4                  Corso di Porta Ticinese, 83, Milano          2     5.0
# ..                                                 ...        ...     ...
# 160                         Via Milano, Cassano d'Adda          2     3.0
# 161                       Via Carlo Farini, 44, Milano          5     3.0
# 162                        Viale Teodorico, 32, Milano          0     0.0
# 163  14, Via Faa' Di Bruno Emilio, Milano, MI 20137...          0     0.0
# 164                          Viale Abruzzi, 90, Milano          0     0.0
#
# [165 rows x 4 columns]

# %% [markdown]
# # Bayesian average
#
# We will use the following bayesian correction:
#
# $$b_i = \frac{m_i}{m_i+M}\cdot s_i + \frac{M}{m_i+M}\cdot S$$
#
# * $b_i$ bayesian corrected rating for item $i$
# * $m_i$ number of reviews for item $i$
# * $s_i$ average rating for item $i$
# * $M$ average number of reviews over the whole dataset
# * $S$ average rating over the whole dataset
#
# **References**
# * https://arpitbhayani.me/blogs/bayesian-average/
# * https://www.youtube.com/watch?v=8idr1WZ1A7Q&list=PL4cNQ1YkG5WhQGmPnRe4vDUImh_nviriy
# * https://www.johndcook.com/blog/2011/09/27/bayesian-amazon/

# %%
# average rating
S = df["rating"].mean()

# average n_reviews
M = df["n_reviews"].mean()

# def bayesian average fun
def bayes_avg(m_i, s_i, M, S):
  """
  Compute the bayeasian average
  """
  return round((m_i*s_i)/(m_i + M) + (M*S)/(m_i + M), 2)

# create column for bayes
df["bayes_rating"] = df.apply(lambda x: bayes_avg(x.n_reviews, x.rating, M, S), axis=1)

# create column for cumulative rating
df["cumulative_rating"] = df.apply(lambda x: round(x.n_reviews*x.rating), axis=1)

# sort by bayes rating
df = df.sort_values(by="bayes_rating", ascending=False).reset_index(drop=True)

# %%
df.head(20)
# Out:
#                                                  name  \
# 0                Tandoori Kebab Halal Food Ristorante
# 1                              Kebabbar - Star Zagros
# 2                  Turkish kebap-pizza-grill-Imbonati
# 3                           Pizza Kebap Senza Cipolla
# 4                          Kebhouze - Cinque Giornate
# 5               Cassala Turkish Kebap - Pizza - Grill
# 6                                       Turkish Kebap
# 7                              İSTANBUL Turkish Kebap
# 8                    Ayasofya-Santa Sofia Kebap Pizza
# 9                       Anatolia Kebab & Pizza Milano
# 10                                               Pasa
# 11                                   Pasa Kebap Pizza
# 12  Istanbul Turkish Kebap - Pizza-grill di GİAMBE...
# 13       Turkish kebap Pizza ,_ Vle Abruzzi 58 MILANO
# 14                      Istanbul Turkish Kebab Milano
# 15                             Aksaray Istanbul Kebap
# 16                        Royal Turkish Kebap - Pizza
# 17                         Oliva Turkish Mediterraneo
# 18                                            Bosforo
# 19                          Turkish Kebap Borsieri 28
#
#                                          address  n_reviews  rating  \
# 0                       Via Vitruvio, 32, Milano        844     4.7
# 1               Corso Ventidue Marzo, 38, Milano        967     4.6
# 2                 Via Carlo Imbonati, 63, Milano        382     4.7
# 3                       Viale Bligny, 64, Milano        206     4.8
# 4                  Via Amatore Sciesa, 7, Milano        170     4.8
# 5                    Via Carlo Torre, 45, Milano        104     5.0
# 6                                          Milan        404     4.5
# 7          Via Piero della Francesca, 24, Milano        378     4.5
# 8                 Corso Buenos Aires, 72, Milano       1170     4.4
# 9                    Via Giambellino, 15, Milano        836     4.4
# 10                  Via Ponte Seveso, 44, Milano        897     4.4
# 11  20136, Viale Tibaldi 15, via meda 17, Milano        277     4.5
# 12                   Via Giambellino, 64, Milano        251     4.5
# 13                     Viale Abruzzi, 58, Milano        108     4.7
# 14                Via Ambrogio Binda, 28, Milano        202     4.5
# 15                        Corso Lodi, 84, Milano        391     4.4
# 16                 Corso Buenos Aires, 2, Milano        384     4.4
# 17                       Viale Monza, 56, Milano        173     4.5
# 18                      Viale Abruzzi, 1, Milano        168     4.5
# 19               Via Pietro Borsieri, 28, Milano        377     4.4
#
#     bayes_rating  cumulative_rating
# 0           4.59               3967
# 1           4.52               4448
# 2           4.51               1795
# 3           4.47                989
# 4           4.44                816
# 5           4.43                520
# 6           4.38               1818
# 7           4.37               1701
# 8           4.36               5148
# 9           4.35               3678
# 10          4.35               3947
# 11          4.34               1246
# 12          4.33               1130
# 13          4.33                508
# 14          4.31                909
# 15          4.31               1720
# 16          4.31               1690
# 17          4.30                778
# 18          4.30                756
# 19          4.30               1659

# %%
df.tail(20)
# Out:
#                                                   name  \
# 145                                Sultan Kebap Milano
# 146                             Pizza-Kebab Di Cairoli
# 147                                 Pizzeria San Karas
# 148                                    Fly Pizza Kebab
# 149  Saray Döner Kebap - Pizza - Grill - Forno a legna
# 150                                           Mr. Poli
# 151                                       Sapori Reali
# 152                                 Padova Pizza Kebab
# 153                                  King Kebab Milano
# 154                                   Kebhouze - Sarpi
# 155                                          ILK Kebap
# 156  Pizzeria Il Faraone...kebab..trattoria...cucin...
# 157                            Kebab e pizza Garibaldi
# 158                                        Dream Kebab
# 159                         HELA Chicken Pizza & Kebab
# 160                                      Turkish Kebab
# 161                                     Kimos Pizzeria
# 162                               Istanbul Doner Kebab
# 163                              Kebab Pizza Cleopatra
# 164                             Centrale Turkish Kebap
#
#                                     address  n_reviews  rating  bayes_rating  \
# 145        Via Lodovico Settala, 68, Milano         76     3.7          3.99
# 146       Via Manfredo Camperio, 17, Milano         35     3.3          3.98
# 147           Via Frà Cristoforo, 1, Milano        135     3.8          3.98
# 148  Via Evangelista Torricelli, 15, Milano         89     3.7          3.98
# 149       Piazza Guglielmo Miani, 4, Milano        103     3.7          3.97
# 150               Viale Romagna, 43, Milano        416     3.9          3.97
# 151               Viale Romagna, 56, Milano        168     3.8          3.96
# 152                  Via Padova, 80, Milano         61     3.5          3.96
# 153                                   Milan         42     3.2          3.95
# 154             Via Paolo Sarpi, 53, Milano        592     3.9          3.95
# 155                 Via Orefici, 24, Milano        231     3.8          3.94
# 156              Viale Certosa, 149, Milano        225     3.8          3.94
# 157               Viale Pasubio, 12, Milano        152     3.7          3.93
# 158      Piazzale Vincenzo Cuoco, 4, Milano        113     3.6          3.92
# 159                 Via Padova, 181, Milano        171     3.7          3.92
# 160                   Via Edolo, 42, Milano         59     3.3          3.92
# 161          Via Bruno Cassinari, 3, Milano        281     3.8          3.92
# 162           Piazzale Selinunte, 6, Milano        345     3.8          3.91
# 163         Via Roberto Lepetit, 16, Milano         92     3.4          3.88
# 164         Piazza Duca d'Aosta, 12, Milano        503     3.1          3.37
#
#      cumulative_rating
# 145                281
# 146                116
# 147                513
# 148                329
# 149                381
# 150               1622
# 151                638
# 152                214
# 153                134
# 154               2309
# 155                878
# 156                855
# 157                562
# 158                407
# 159                633
# 160                195
# 161               1068
# 162               1311
# 163                313
# 164               1559

# %%
# df.to_excel("kebab_df.xlsx")
